# %%
import pandas as pd
import numpy as np
from sklearn import tree

# %%
df =  pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data")
df.head()
# Out:
#    B  1  1.1  1.2  1.3
# 0  R  1    1    1    2
# 1  R  1    1    1    3
# 2  R  1    1    1    4
# 3  R  1    1    1    5
# 4  R  1    1    2    1

# %%
df.shape
# Out:
# (624, 5)

# %%
df2 = np.array(df.loc[:,['B']])
df2
# Out:
# array([['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['L'],
#        ['B'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['B'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['L'],
#        ['L'],
#        ['B'],
#        ['R'],
#        ['R'],
#        ['L'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['R'],
#        ['B'],
#        ['R'],
#        ['R'],
# ...

# %%
df1 = df.drop(['B'],axis=1)
df1.head()
# Out:
#    1  1.1  1.2  1.3
# 0  1    1    1    2
# 1  1    1    1    3
# 2  1    1    1    4
# 3  1    1    1    5
# 4  1    1    2    1

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25,random_state = 1)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (468, 4) (468, 1)
# (156, 4) (156, 1)

# %%
x = np.array(df1)
y = np.array(df2)
x.shape
y.shape
# Out:
# (624, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_leaf_nodes=60, max_depth=10)
model.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=60,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
score =  model.score(X_test,Y_test)
print(score)
# Out:
# 0.8076923076923077

# %%
from sklearn.tree import DecisionTreeClassifier
model1 = DecisionTreeClassifier(criterion = 'entropy',max_leaf_nodes=40, max_depth=10)
model1.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=40,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
score =  model1.score(X_test,Y_test)
print(score)
# Out:
# 0.8012820512820513

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
model4 = RandomForestClassifier()
model4.fit(X_train , Y_train.reshape(468,))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
score =  model4.score(X_test,Y_test)
print(score)
# Out:
# 0.8205128205128205

# %%
model5 = RandomForestClassifier(criterion = 'entropy', max_leaf_nodes=20, max_depth=25)
model5.fit(X_train , Y_train.reshape(468,))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=25, max_features='auto', max_leaf_nodes=20,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
score =  model5.score(X_test,Y_test)
print(score)
# Out:
# 0.8846153846153846
