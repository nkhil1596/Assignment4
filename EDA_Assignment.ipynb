# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# 5      False  False  False     False      False        False     False
# 6      False  False  False     False      False        False     False
# 7      False  False  False     False      False        False     False
# 8      False  False  False     False      False        False     False
# 9      False  False  False     False      False        False     False
# 10     False  False  False     False      False        False     False
# 11     False  False  False     False      False        False     False
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df1=df.head()
df1
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
sns.distplot(df1['price'],kde = True)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(df1['price'])

# %%
sns.boxplot(df1['bathrooms'])

# %%
sns.boxplot(df1['bedrooms'])

# %%
sns.boxplot(df1['sqft_living'])

# %%
sns.boxplot(df1['sqft_lot'])

# %%
sns.boxplot(df1['floors'])

# %%
sns.boxplot(df1['sqft_above'])

# %%
sns.boxplot(df1['sqft_basement'])

# %%
sns.boxplot(df1['yr_built'])

# %%
sns.boxplot(df1['yr_renovated'])

# %%
sns.boxplot(df1['zipcode'])

# %%
sns.boxplot(df1['lat'])

# %%
sns.boxplot(df1['long'])

# %%
sns.boxplot(df1['sqft_living15'])

# %%
sns.boxplot(df1['sqft_lot15'])

# %% [markdown]
# # Bi_Variate_Analysis

# %%
df1.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df1.count()
# Out:
# id               5
# date             5
# price            5
# bedrooms         5
# bathrooms        5
# sqft_living      5
# sqft_lot         5
# floors           5
# waterfront       5
# view             5
# condition        5
# grade            5
# sqft_above       5
# sqft_basement    5
# yr_built         5
# yr_renovated     5
# zipcode          5
# lat              5
# long             5
# sqft_living15    5
# sqft_lot15       5
# dtype: int64

# %%
plt.scatter(df1['sqft_living'],df1['sqft_lot'],c='g', marker = "^")

# %%
sns.countplot(hue='sqft_living15', x='bedrooms',data=df1)

# %%
sns.countplot(hue='sqft_living15', x='bathrooms',data=df1)

# %%
sns.barplot(hue='sqft_living15', x='sqft_basement',y='sqft_above',data=df1)

# %%
sns.stripplot(x='sqft_basement',y='sqft_above',hue='sqft_living15',data =df1)

# %% [markdown]
# # Multi_Variate_Analysis

# %%
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr)

# %%
sns.boxplot(df1[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','view']])

# %% [markdown]
# # Final Plots – Select 3 most interesting graphs from the above analysis and describe why those graphs are chosen.

# %%
sns.boxplot(df1['yr_built'])

# %%
The above graph I choose for the uni-variate data as this shows the year of buildation of the house.And from the graph I can see
that the graph is not normally distributed, the graph is skewwed.

# %%
sns.barplot(hue='sqft_living15', x='sqft_basement',y='sqft_above',data=df1)

# %%
For the bi-variate data I choose the above graph because it shows the sqft_living by alloting values when sqft_above on the x-axis
and sqft_basement on the y-axis is provided on the barplot.

# %%
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr)

# %%
For the multi-variate data the heat-map plotting is plotted above which shows the coo-relation between all the attributes.
